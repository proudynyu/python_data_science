# %%
import numpy as np

x = np.random.normal(size=50)
print(x)
# Out:
# [-1.10157945  0.00318228  0.08786112  0.53477083  0.75286717 -0.11847388
#  -0.68903846  2.57455732  0.07550225 -0.26576634  0.01706784 -0.60149165
#  -0.0238804   0.67912937  1.99297447  0.35309556  0.57204107  0.70222366
#   1.54730995  0.05178039 -0.54822037  1.00645664  0.31279051 -0.56792757
#   0.21000749 -0.97305686  1.90992247  0.85845527 -1.74606255 -0.14026921
#  -0.16552832 -0.45055922  0.0989309   2.0030927   0.14488332  0.44918342
#   0.5184788  -0.31063287  0.39174886  2.16547094 -0.56040551 -0.73664508
#  -0.48065536 -0.36615047  0.12096022  1.07546661 -0.79185568 -0.36064745
#  -1.08190544 -0.96102821]

# %%
y = x + np.random.normal(loc=50, scale=1, size=50)
print(y)
# Out:
# [48.48797281 49.79882552 50.13010678 51.00441175 49.82752548 49.07190219
#  50.50188852 53.49709191 49.77918666 48.9047554  50.61865335 49.37336842
#  49.29928211 50.31496112 51.63213726 49.45311412 51.29644227 48.79367002
#  51.03497643 49.56529739 49.4985649  50.68185419 49.51882123 48.83905328
#  49.71717076 49.37453195 50.84326154 50.45070915 49.94006775 51.02001191
#  50.37725417 49.48978148 50.60599332 51.67221804 49.19392126 50.81723117
#  50.51122333 50.11369165 51.15025665 51.22756627 48.93580747 47.72131496
#  50.049032   49.47599212 50.6225549  49.87504609 47.54420634 49.67441528
#  49.20645035 49.32920742]

# %%
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.71058491],
#        [0.71058491, 1.        ]])

# %%
rnd = np.random.default_rng(1303)
print(rnd.normal(scale=5, size=2))
rnd2 = np.random.default_rng(1303)
print(rnd2.normal(scale=5, size=2))

# %%
rng = np.random.default_rng(3)
y = rng.standard_normal(10)
np.mean(y)

# %%
np.mean((y - y.mean()) ** 2) , np.var(y), y.var()

# %%
X = rng.standard_normal((10, 3))
print(X)

# %%
X.mean(axis=0)

# %%
from matplotlib.pyplot import subplots
fig, ax = subplots(figsize=(8,8))
x = rng.standard_normal(100)
y = rng.standard_normal(100)

ax.plot(x, y, 'o')

# %%
ax.scatter(x, y, marker='o')
ax.set_xlabel('x label')
ax.set_ylabel('y_label')
ax.set_title('Plotting')
fig.set_size_inches(12, 3)

# %%
fig, ax = subplots(figsize=(8,8))
x = np.linspace(-np.pi, np.pi, 50)
y = x
f = np.multiply.outer(np.cos(y), 1 / (1 + x**2))
ax.contour(x, y, f)
