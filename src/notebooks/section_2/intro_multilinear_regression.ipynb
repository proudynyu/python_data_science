# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from helper import fit_and_plot_linear, fit_and_plot_multi
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 4
#       1 import numpy as np
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 from helper import fit_and_plot_linear, fit_and_plot_multi, fit_linear
#
# ImportError: cannot import name 'fit_linear' from 'helper' (/home/igor/dev/python_data_science/src/notebooks/section_2/helper.py)

# %%
filename = "../data/sales_predictors.csv"
df = pd.read_csv(filename)
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df_results = pd.DataFrame(columns=['Predictor', 'R2 Train', 'R2 Test'])
predictors = df.columns.values[:-1]
print(predictors)
# Out:
# <StringArray>
# ['TV', 'Radio', 'Newspaper']
# Length: 3, dtype: str

# %%
for pred in predictors:
    df_t = df[[pred]]
    fit_and_plot_linear(df_t)

# %%
fit_and_plot_multi()
# Out:
# (0.9067114990146383, 0.8601145185017868)

# %%
for pred in predictors:
    df_t = df[[pred]]
    r2_train, r2_test = fit_and_plot_linear(df_t)
    df_results.loc[len(df_results)] = {
        'Predictor': pred, 'R2 Train': r2_train, 'R2 Test': r2_test
    }

# %%
df_results.head()
# Out:
#    Predictor  R2 Train   R2 Test
# 0         TV  0.588474  0.676315
# 1      Radio  0.356718  0.229817
# 2  Newspaper  0.064416 -0.021217
